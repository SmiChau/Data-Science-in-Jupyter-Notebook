# %%
import numpy as np

# %%
a=[1,2,3,4,5]

# %%
np.array(a)
# Out:
# array([1, 2, 3, 4, 5])

# %%
arr.dtype(a)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 arr.dtype(a)
#
# NameError: name 'arr' is not defined

# %%
arr=np.array(a, dtype)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 arr=np.array(a, dtype)
#
# NameError: name 'dtype' is not defined

# %%
arr=np.array(a)

# %%
arr.dtype()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 arr.dtype()
#
# TypeError: 'numpy.dtypes.Int64DType' object is not callable

# %%
arr=np.array(a, dtype=int32)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 arr=np.array(a, dtype=int32)
#
# NameError: name 'int32' is not defined
